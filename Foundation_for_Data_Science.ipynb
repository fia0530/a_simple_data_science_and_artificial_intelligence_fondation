# %% [markdown]
# Contoh Studi Kasus

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **SOAL 1**

# %% [markdown]
# 1. Identifikasi dan jelaskan tipe data apa saja yang ada pada dataframe, ada berapa kolom dan baris, serta informasi apa saja yang terkandung dalam data tersebut?

# %%
df_15=pd.read_excel('DataKompi15.xlsx')

# %%
df_15.shape
# Out:
# (25, 5)

# %%
df_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   No. Peserta        25 non-null     object
#  1   Nama               25 non-null     object
#  2   Jurusan            25 non-null     object
#  3   Berat Badan (kg)   25 non-null     int64
#  4   Tinggi Badan (cm)  25 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 1.1+ KB

# %% [markdown]
# 2. Hitunglah BMI setiap siswa dengan rumus BMI=Berat badan (kg) / (Tinggi Badan (m))2

# %%
df_15["Tinggi Badan (cm)"] = df_15["Tinggi Badan (cm)"] / 100

# %%
df_15.rename(columns={'Tinggi Badan (cm)': 'Tinggi Badan (m)'}, inplace=True)

# %%
df_15.head()
# Out:
#   No. Peserta                      Nama             Jurusan  Berat Badan (kg)  \
# 0     SC61501        Aisyah Fitri Kania    Sistem Informasi                54
# 1     SC61502  Asmal Adyatma Siolimbona  Teknik Informatika                69
# 2     SC61503              Devia Heraka           Kearsipan                48
# 3     SC61504        Fauzia Khairunnisa          Matematika                42
# 4     SC61505              Indah Kurnia     Teknik Industri                48
#
#    Tinggi Badan (m)
# 0              1.56
# 1              1.74
# 2              1.45
# 3              1.55
# 4              1.55

# %%
def rumus_bmi():
  x=df_15['Berat Badan (kg)']
  y=df_15['Tinggi Badan (m)']

  BMI = x / (y**2)

  return BMI

# %%
rumus_bmi()
# Out:
# 0     22.189349
# 1     22.790329
# 2     22.829964
# 3     17.481790
# 4     19.979188
# 5     21.799308
# 6     20.761246
# 7     21.359915
# 8     19.146722
# 9     22.892820
# 10    23.040020
# 11    22.031726
# 12    17.968750
# 13    18.424036
# 14    28.906250
# 15    21.096191
# 16    22.031726
# 17    20.761246
# 18    21.208449
# 19    24.221453
# 20    23.437500
# 21    18.256319
# 22    22.656250
# 23    17.993080
# 24    22.806017
# dtype: float64

# %% [markdown]
# 3. Buatlah program untuk menghitung BMI!

# %%
def bmi():
  x=int(input('Berat Badan (kg)='))
  y=float(input('Tinggi Badan (m)='))

  BMI = x / (y**2)

  return BMI

# %%
bmi()
# Out:
# Berat Badan (kg)=40
# Tinggi Badan (m)=155
# 0.0016649323621227888

# %% [markdown]
# 4. Update dataframe df dengan menambahkan hasil perhitungan soal nomor 2, beri nama kolom BMI.

# %%
df_15['BMI'] = df_15['Berat Badan (kg)'] / (df_15['Tinggi Badan (m)'] **2)

# %%
df_15
# Out:
#    No. Peserta                          Nama  \
# 0      SC61501            Aisyah Fitri Kania
# 1      SC61502      Asmal Adyatma Siolimbona
# 2      SC61503                  Devia Heraka
# 3      SC61504            Fauzia Khairunnisa
# 4      SC61505                  Indah Kurnia
# 5      SC61506       M. Ivan Nuruddin Ishaqi
# 6      SC61507                Muhammad Durra
# 7      SC61508          Nasywa Anindya Putri
# 8      SC61509               Qonita Qorirroh
# 9      SC61510   Sandya Nur Indrawati Karsan
# 10     SC61511               Wahyu Dwi Utomo
# 11     SC61512                      Angelina
# 12     SC61513      Dhini Nurawiati Purwanda
# 13     SC61514               Hikmal Aprilian
# 14     SC61515          Litasya Shofwatillah
# 15     SC61516         Muhammad Rizki Taufik
# 16     SC61517  Radya Ardi Ninang Pudyastuti
# 17     SC61518         Nadira Alivia Mustopo
# 18     SC61519             Amalia Rama Dhani
# 19     SC61520                     Beni Amar
# 20     SC61521                   Fikri Majid
# 21     SC61522                Luthfia Amanah
# 22     SC61523           Niken Ari Wijayanti
# 23     SC61524                 Sandy Febrian
# 24     SC61525         Zafirah Yaffa Zabrina
#
#                                Jurusan  Berat Badan (kg)  Tinggi Badan (m)  \
# 0                     Sistem Informasi                54              1.56
# 1                   Teknik Informatika                69              1.74
# 2                            Kearsipan                48              1.45
# 3                           Matematika                42              1.55
# 4                      Teknik Industri                48              1.55
# 5                           Matematika                63              1.70
# 6                   Teknik Informatika                60              1.70
# 7                            Psikologi                54              1.59
# 8                            Manajemen                46              1.55
# 9                           Matematika                55              1.55
# 10                    Sistem Informasi                73              1.78
# 11                  Teknik Informatika                55              1.58
# 12                    Sistem Informasi                46              1.60
# 13                          Statistika                52              1.68
# 14                          Statistika                74              1.60
# 15                 Ekonomi Pembangunan                52              1.57
# 16                          Sains Data                55              1.58
# 17                        Ilmu Ekonomi                60              1.70
# 18                      Teknik Elektro                49              1.52
# 19  Sistem Informasi Kampus Kota Tegal                70              1.70
# 20         Teknologi Rekayasa Komputer                60              1.60
# 21                          Matematika                45              1.57
# 22                          Matematika                58              1.60
# 23                  Teknik Informatika                52              1.70
# 24                           Akuntansi                52              1.51
#
#           BMI
# 0   22.189349
# 1   22.790329
# 2   22.829964
# 3   17.481790
# 4   19.979188
# 5   21.799308
# 6   20.761246
# 7   21.359915
# 8   19.146722
# 9   22.892820
# 10  23.040020
# 11  22.031726
# 12  17.968750
# 13  18.424036
# 14  28.906250
# 15  21.096191
# 16  22.031726
# 17  20.761246
# 18  21.208449
# 19  24.221453
# 20  23.437500
# 21  18.256319
# 22  22.656250
# 23  17.993080
# 24  22.806017

# %% [markdown]
# 5. Buatlah status BMI untuk setiap siswa dari kategori berikut, lalu simpan data statusnya dengan nama kolom Status BMI.
# * Normal: 18.5-24.9
# * Overweight: 25.0-29.9
# * Obesity: 30.0-34.9
# * Underweight: < 18.5

# %%
def status_bmi(bmi):
    if bmi < 18.5:
        return 'Underweight'
    elif 18.5 <= bmi <= 24.9:
        return 'Normal'
    elif 25.0 <= bmi <= 29.9:
        return 'Overweight'
    elif 30.0 <= bmi <= 34.9:
        return 'Obesity'
    else:
        return 'Invalid'

# %%
df_15['BMI_status'] = df_15['BMI'].apply(status_bmi)

# %%
df_15
# Out:
#    No. Peserta                          Nama  \
# 0      SC61501            Aisyah Fitri Kania
# 1      SC61502      Asmal Adyatma Siolimbona
# 2      SC61503                  Devia Heraka
# 3      SC61504            Fauzia Khairunnisa
# 4      SC61505                  Indah Kurnia
# 5      SC61506       M. Ivan Nuruddin Ishaqi
# 6      SC61507                Muhammad Durra
# 7      SC61508          Nasywa Anindya Putri
# 8      SC61509               Qonita Qorirroh
# 9      SC61510   Sandya Nur Indrawati Karsan
# 10     SC61511               Wahyu Dwi Utomo
# 11     SC61512                      Angelina
# 12     SC61513      Dhini Nurawiati Purwanda
# 13     SC61514               Hikmal Aprilian
# 14     SC61515          Litasya Shofwatillah
# 15     SC61516         Muhammad Rizki Taufik
# 16     SC61517  Radya Ardi Ninang Pudyastuti
# 17     SC61518         Nadira Alivia Mustopo
# 18     SC61519             Amalia Rama Dhani
# 19     SC61520                     Beni Amar
# 20     SC61521                   Fikri Majid
# 21     SC61522                Luthfia Amanah
# 22     SC61523           Niken Ari Wijayanti
# 23     SC61524                 Sandy Febrian
# 24     SC61525         Zafirah Yaffa Zabrina
#
#                                Jurusan  Berat Badan (kg)  Tinggi Badan (m)  \
# 0                     Sistem Informasi                54              1.56
# 1                   Teknik Informatika                69              1.74
# 2                            Kearsipan                48              1.45
# 3                           Matematika                42              1.55
# 4                      Teknik Industri                48              1.55
# 5                           Matematika                63              1.70
# 6                   Teknik Informatika                60              1.70
# 7                            Psikologi                54              1.59
# 8                            Manajemen                46              1.55
# 9                           Matematika                55              1.55
# 10                    Sistem Informasi                73              1.78
# 11                  Teknik Informatika                55              1.58
# 12                    Sistem Informasi                46              1.60
# 13                          Statistika                52              1.68
# 14                          Statistika                74              1.60
# 15                 Ekonomi Pembangunan                52              1.57
# 16                          Sains Data                55              1.58
# 17                        Ilmu Ekonomi                60              1.70
# 18                      Teknik Elektro                49              1.52
# 19  Sistem Informasi Kampus Kota Tegal                70              1.70
# 20         Teknologi Rekayasa Komputer                60              1.60
# 21                          Matematika                45              1.57
# 22                          Matematika                58              1.60
# 23                  Teknik Informatika                52              1.70
# 24                           Akuntansi                52              1.51
#
#           BMI   BMI_status
# 0   22.189349       Normal
# 1   22.790329       Normal
# 2   22.829964       Normal
# 3   17.481790  Underweight
# 4   19.979188       Normal
# 5   21.799308       Normal
# 6   20.761246       Normal
# 7   21.359915       Normal
# 8   19.146722       Normal
# 9   22.892820       Normal
# 10  23.040020       Normal
# 11  22.031726       Normal
# 12  17.968750  Underweight
# 13  18.424036  Underweight
# 14  28.906250   Overweight
# 15  21.096191       Normal
# 16  22.031726       Normal
# 17  20.761246       Normal
# 18  21.208449       Normal
# 19  24.221453       Normal
# 20  23.437500       Normal
# 21  18.256319  Underweight
# 22  22.656250       Normal
# 23  17.993080  Underweight
# 24  22.806017       Normal

# %% [markdown]
# 6. a. Buatlah variabel baru lalu urutkan data berdasarkan tinggi badan dari yang tertinggi ke rendah.
#
#
#
#
# ---

# %%
df_15_sorted_tinggi = df_15.sort_values("Tinggi Badan (m)", ascending=False)

# %%
df_15_sorted_tinggi
# Out:
#    No. Peserta                          Nama  \
# 10     SC61511               Wahyu Dwi Utomo
# 1      SC61502      Asmal Adyatma Siolimbona
# 23     SC61524                 Sandy Febrian
# 5      SC61506       M. Ivan Nuruddin Ishaqi
# 6      SC61507                Muhammad Durra
# 17     SC61518         Nadira Alivia Mustopo
# 19     SC61520                     Beni Amar
# 13     SC61514               Hikmal Aprilian
# 12     SC61513      Dhini Nurawiati Purwanda
# 14     SC61515          Litasya Shofwatillah
# 20     SC61521                   Fikri Majid
# 22     SC61523           Niken Ari Wijayanti
# 7      SC61508          Nasywa Anindya Putri
# 11     SC61512                      Angelina
# 16     SC61517  Radya Ardi Ninang Pudyastuti
# 21     SC61522                Luthfia Amanah
# 15     SC61516         Muhammad Rizki Taufik
# 0      SC61501            Aisyah Fitri Kania
# 9      SC61510   Sandya Nur Indrawati Karsan
# 8      SC61509               Qonita Qorirroh
# 4      SC61505                  Indah Kurnia
# 3      SC61504            Fauzia Khairunnisa
# 18     SC61519             Amalia Rama Dhani
# 24     SC61525         Zafirah Yaffa Zabrina
# 2      SC61503                  Devia Heraka
#
#                                Jurusan  Berat Badan (kg)  Tinggi Badan (m)  \
# 10                    Sistem Informasi                73              1.78
# 1                   Teknik Informatika                69              1.74
# 23                  Teknik Informatika                52              1.70
# 5                           Matematika                63              1.70
# 6                   Teknik Informatika                60              1.70
# 17                        Ilmu Ekonomi                60              1.70
# 19  Sistem Informasi Kampus Kota Tegal                70              1.70
# 13                          Statistika                52              1.68
# 12                    Sistem Informasi                46              1.60
# 14                          Statistika                74              1.60
# 20         Teknologi Rekayasa Komputer                60              1.60
# 22                          Matematika                58              1.60
# 7                            Psikologi                54              1.59
# 11                  Teknik Informatika                55              1.58
# 16                          Sains Data                55              1.58
# 21                          Matematika                45              1.57
# 15                 Ekonomi Pembangunan                52              1.57
# 0                     Sistem Informasi                54              1.56
# 9                           Matematika                55              1.55
# 8                            Manajemen                46              1.55
# 4                      Teknik Industri                48              1.55
# 3                           Matematika                42              1.55
# 18                      Teknik Elektro                49              1.52
# 24                           Akuntansi                52              1.51
# 2                            Kearsipan                48              1.45
#
#           BMI   BMI_status
# 10  23.040020       Normal
# 1   22.790329       Normal
# 23  17.993080  Underweight
# 5   21.799308       Normal
# 6   20.761246       Normal
# 17  20.761246       Normal
# 19  24.221453       Normal
# 13  18.424036  Underweight
# 12  17.968750  Underweight
# 14  28.906250   Overweight
# 20  23.437500       Normal
# 22  22.656250       Normal
# 7   21.359915       Normal
# 11  22.031726       Normal
# 16  22.031726       Normal
# 21  18.256319  Underweight
# 15  21.096191       Normal
# 0   22.189349       Normal
# 9   22.892820       Normal
# 8   19.146722       Normal
# 4   19.979188       Normal
# 3   17.481790  Underweight
# 18  21.208449       Normal
# 24  22.806017       Normal
# 2   22.829964       Normal

# %% [markdown]
# 6. b. Buat variabel baru lalu urutkan data berdasarkan Nama dari Z – A.

# %%
df_15_sorted_nama = df_15.sort_values("Nama", ascending=False)

# %%
df_15_sorted_nama
# Out:
#    No. Peserta                          Nama  \
# 24     SC61525         Zafirah Yaffa Zabrina
# 10     SC61511               Wahyu Dwi Utomo
# 9      SC61510   Sandya Nur Indrawati Karsan
# 23     SC61524                 Sandy Febrian
# 16     SC61517  Radya Ardi Ninang Pudyastuti
# 8      SC61509               Qonita Qorirroh
# 22     SC61523           Niken Ari Wijayanti
# 7      SC61508          Nasywa Anindya Putri
# 17     SC61518         Nadira Alivia Mustopo
# 15     SC61516         Muhammad Rizki Taufik
# 6      SC61507                Muhammad Durra
# 5      SC61506       M. Ivan Nuruddin Ishaqi
# 21     SC61522                Luthfia Amanah
# 14     SC61515          Litasya Shofwatillah
# 4      SC61505                  Indah Kurnia
# 13     SC61514               Hikmal Aprilian
# 20     SC61521                   Fikri Majid
# 3      SC61504            Fauzia Khairunnisa
# 12     SC61513      Dhini Nurawiati Purwanda
# 2      SC61503                  Devia Heraka
# 19     SC61520                     Beni Amar
# 1      SC61502      Asmal Adyatma Siolimbona
# 11     SC61512                      Angelina
# 18     SC61519             Amalia Rama Dhani
# 0      SC61501            Aisyah Fitri Kania
#
#                                Jurusan  Berat Badan (kg)  Tinggi Badan (m)  \
# 24                           Akuntansi                52              1.51
# 10                    Sistem Informasi                73              1.78
# 9                           Matematika                55              1.55
# 23                  Teknik Informatika                52              1.70
# 16                          Sains Data                55              1.58
# 8                            Manajemen                46              1.55
# 22                          Matematika                58              1.60
# 7                            Psikologi                54              1.59
# 17                        Ilmu Ekonomi                60              1.70
# 15                 Ekonomi Pembangunan                52              1.57
# 6                   Teknik Informatika                60              1.70
# 5                           Matematika                63              1.70
# 21                          Matematika                45              1.57
# 14                          Statistika                74              1.60
# 4                      Teknik Industri                48              1.55
# 13                          Statistika                52              1.68
# 20         Teknologi Rekayasa Komputer                60              1.60
# 3                           Matematika                42              1.55
# 12                    Sistem Informasi                46              1.60
# 2                            Kearsipan                48              1.45
# 19  Sistem Informasi Kampus Kota Tegal                70              1.70
# 1                   Teknik Informatika                69              1.74
# 11                  Teknik Informatika                55              1.58
# 18                      Teknik Elektro                49              1.52
# 0                     Sistem Informasi                54              1.56
#
#           BMI   BMI_status
# 24  22.806017       Normal
# 10  23.040020       Normal
# 9   22.892820       Normal
# 23  17.993080  Underweight
# 16  22.031726       Normal
# 8   19.146722       Normal
# 22  22.656250       Normal
# 7   21.359915       Normal
# 17  20.761246       Normal
# 15  21.096191       Normal
# 6   20.761246       Normal
# 5   21.799308       Normal
# 21  18.256319  Underweight
# 14  28.906250   Overweight
# 4   19.979188       Normal
# 13  18.424036  Underweight
# 20  23.437500       Normal
# 3   17.481790  Underweight
# 12  17.968750  Underweight
# 2   22.829964       Normal
# 19  24.221453       Normal
# 1   22.790329       Normal
# 11  22.031726       Normal
# 18  21.208449       Normal
# 0   22.189349       Normal

# %% [markdown]
# 7. Filter dataframe df berdasarkan:
# * Status BMI di luar Normal.

# %%
df_15[df_15['BMI_status'] != 'Normal']
# Out:
#    No. Peserta                      Nama             Jurusan  \
# 3      SC61504        Fauzia Khairunnisa          Matematika
# 12     SC61513  Dhini Nurawiati Purwanda    Sistem Informasi
# 13     SC61514           Hikmal Aprilian          Statistika
# 14     SC61515      Litasya Shofwatillah          Statistika
# 21     SC61522            Luthfia Amanah          Matematika
# 23     SC61524             Sandy Febrian  Teknik Informatika
#
#     Berat Badan (kg)  Tinggi Badan (m)        BMI   BMI_status
# 3                 42              1.55  17.481790  Underweight
# 12                46              1.60  17.968750  Underweight
# 13                52              1.68  18.424036  Underweight
# 14                74              1.60  28.906250   Overweight
# 21                45              1.57  18.256319  Underweight
# 23                52              1.70  17.993080  Underweight

# %% [markdown]
# * Tinggi Badan > 169 cm dan Berat Badan > 60 kg

# %%
df_15[(df_15['Tinggi Badan (m)'] > 1.69) & (df_15['Berat Badan (kg)'] > 60)]
# Out:
#    No. Peserta                      Nama                             Jurusan  \
# 1      SC61502  Asmal Adyatma Siolimbona                  Teknik Informatika
# 5      SC61506   M. Ivan Nuruddin Ishaqi                          Matematika
# 10     SC61511           Wahyu Dwi Utomo                    Sistem Informasi
# 19     SC61520                 Beni Amar  Sistem Informasi Kampus Kota Tegal
#
#     Berat Badan (kg)  Tinggi Badan (m)        BMI BMI_status
# 1                 69              1.74  22.790329     Normal
# 5                 63              1.70  21.799308     Normal
# 10                73              1.78  23.040020     Normal
# 19                70              1.70  24.221453     Normal

# %% [markdown]
# * Nama yang mengandung huruf “y”.

# %%
df_15[df_15['Nama'].str.contains('y', case=False)]
# Out:
#    No. Peserta                          Nama             Jurusan  \
# 0      SC61501            Aisyah Fitri Kania    Sistem Informasi
# 1      SC61502      Asmal Adyatma Siolimbona  Teknik Informatika
# 7      SC61508          Nasywa Anindya Putri           Psikologi
# 9      SC61510   Sandya Nur Indrawati Karsan          Matematika
# 10     SC61511               Wahyu Dwi Utomo    Sistem Informasi
# 14     SC61515          Litasya Shofwatillah          Statistika
# 16     SC61517  Radya Ardi Ninang Pudyastuti          Sains Data
# 22     SC61523           Niken Ari Wijayanti          Matematika
# 23     SC61524                 Sandy Febrian  Teknik Informatika
# 24     SC61525         Zafirah Yaffa Zabrina           Akuntansi
#
#     Berat Badan (kg)  Tinggi Badan (m)        BMI   BMI_status
# 0                 54              1.56  22.189349       Normal
# 1                 69              1.74  22.790329       Normal
# 7                 54              1.59  21.359915       Normal
# 9                 55              1.55  22.892820       Normal
# 10                73              1.78  23.040020       Normal
# 14                74              1.60  28.906250   Overweight
# 16                55              1.58  22.031726       Normal
# 22                58              1.60  22.656250       Normal
# 23                52              1.70  17.993080  Underweight
# 24                52              1.51  22.806017       Normal

# %% [markdown]
# * Siapa saja yang berat badannya kurang dari 60 kg?

# %%
df_15[df_15['Berat Badan (kg)'] < 60]
# Out:
#    No. Peserta                          Nama              Jurusan  \
# 0      SC61501            Aisyah Fitri Kania     Sistem Informasi
# 2      SC61503                  Devia Heraka            Kearsipan
# 3      SC61504            Fauzia Khairunnisa           Matematika
# 4      SC61505                  Indah Kurnia      Teknik Industri
# 7      SC61508          Nasywa Anindya Putri            Psikologi
# 8      SC61509               Qonita Qorirroh            Manajemen
# 9      SC61510   Sandya Nur Indrawati Karsan           Matematika
# 11     SC61512                      Angelina   Teknik Informatika
# 12     SC61513      Dhini Nurawiati Purwanda     Sistem Informasi
# 13     SC61514               Hikmal Aprilian           Statistika
# 15     SC61516         Muhammad Rizki Taufik  Ekonomi Pembangunan
# 16     SC61517  Radya Ardi Ninang Pudyastuti           Sains Data
# 18     SC61519             Amalia Rama Dhani       Teknik Elektro
# 21     SC61522                Luthfia Amanah           Matematika
# 22     SC61523           Niken Ari Wijayanti           Matematika
# 23     SC61524                 Sandy Febrian   Teknik Informatika
# 24     SC61525         Zafirah Yaffa Zabrina            Akuntansi
#
#     Berat Badan (kg)  Tinggi Badan (m)        BMI   BMI_status
# 0                 54              1.56  22.189349       Normal
# 2                 48              1.45  22.829964       Normal
# 3                 42              1.55  17.481790  Underweight
# 4                 48              1.55  19.979188       Normal
# 7                 54              1.59  21.359915       Normal
# 8                 46              1.55  19.146722       Normal
# 9                 55              1.55  22.892820       Normal
# 11                55              1.58  22.031726       Normal
# 12                46              1.60  17.968750  Underweight
# 13                52              1.68  18.424036  Underweight
# 15                52              1.57  21.096191       Normal
# 16                55              1.58  22.031726       Normal
# 18                49              1.52  21.208449       Normal
# 21                45              1.57  18.256319  Underweight
# 22                58              1.60  22.656250       Normal
# 23                52              1.70  17.993080  Underweight
# 24                52              1.51  22.806017       Normal

# %% [markdown]
# 8. Tambahkan nomor urut pada dataframe df sesuai jumlah siswa dan tempatkan kolom nomor baru tersebut di paling ujung kiri sebagai kolom pertama serta beri nama kolomnya “No.”!

# %%
df_15.insert(0, 'No.', range(1, len(df_15) + 1))

# %%
df_15
# Out:
#     No. No. Peserta                          Nama  \
# 0     1     SC61501            Aisyah Fitri Kania
# 1     2     SC61502      Asmal Adyatma Siolimbona
# 2     3     SC61503                  Devia Heraka
# 3     4     SC61504            Fauzia Khairunnisa
# 4     5     SC61505                  Indah Kurnia
# 5     6     SC61506       M. Ivan Nuruddin Ishaqi
# 6     7     SC61507                Muhammad Durra
# 7     8     SC61508          Nasywa Anindya Putri
# 8     9     SC61509               Qonita Qorirroh
# 9    10     SC61510   Sandya Nur Indrawati Karsan
# 10   11     SC61511               Wahyu Dwi Utomo
# 11   12     SC61512                      Angelina
# 12   13     SC61513      Dhini Nurawiati Purwanda
# 13   14     SC61514               Hikmal Aprilian
# 14   15     SC61515          Litasya Shofwatillah
# 15   16     SC61516         Muhammad Rizki Taufik
# 16   17     SC61517  Radya Ardi Ninang Pudyastuti
# 17   18     SC61518         Nadira Alivia Mustopo
# 18   19     SC61519             Amalia Rama Dhani
# 19   20     SC61520                     Beni Amar
# 20   21     SC61521                   Fikri Majid
# 21   22     SC61522                Luthfia Amanah
# 22   23     SC61523           Niken Ari Wijayanti
# 23   24     SC61524                 Sandy Febrian
# 24   25     SC61525         Zafirah Yaffa Zabrina
#
#                                Jurusan  Berat Badan (kg)  Tinggi Badan (m)  \
# 0                     Sistem Informasi                54              1.56
# 1                   Teknik Informatika                69              1.74
# 2                            Kearsipan                48              1.45
# 3                           Matematika                42              1.55
# 4                      Teknik Industri                48              1.55
# 5                           Matematika                63              1.70
# 6                   Teknik Informatika                60              1.70
# 7                            Psikologi                54              1.59
# 8                            Manajemen                46              1.55
# 9                           Matematika                55              1.55
# 10                    Sistem Informasi                73              1.78
# 11                  Teknik Informatika                55              1.58
# 12                    Sistem Informasi                46              1.60
# 13                          Statistika                52              1.68
# 14                          Statistika                74              1.60
# 15                 Ekonomi Pembangunan                52              1.57
# 16                          Sains Data                55              1.58
# 17                        Ilmu Ekonomi                60              1.70
# 18                      Teknik Elektro                49              1.52
# 19  Sistem Informasi Kampus Kota Tegal                70              1.70
# 20         Teknologi Rekayasa Komputer                60              1.60
# 21                          Matematika                45              1.57
# 22                          Matematika                58              1.60
# 23                  Teknik Informatika                52              1.70
# 24                           Akuntansi                52              1.51
#
#           BMI   BMI_status
# 0   22.189349       Normal
# 1   22.790329       Normal
# 2   22.829964       Normal
# 3   17.481790  Underweight
# 4   19.979188       Normal
# 5   21.799308       Normal
# 6   20.761246       Normal
# 7   21.359915       Normal
# 8   19.146722       Normal
# 9   22.892820       Normal
# 10  23.040020       Normal
# 11  22.031726       Normal
# 12  17.968750  Underweight
# 13  18.424036  Underweight
# 14  28.906250   Overweight
# 15  21.096191       Normal
# 16  22.031726       Normal
# 17  20.761246       Normal
# 18  21.208449       Normal
# 19  24.221453       Normal
# 20  23.437500       Normal
# 21  18.256319  Underweight
# 22  22.656250       Normal
# 23  17.993080  Underweight
# 24  22.806017       Normal

# %% [markdown]
# 9. Cari nilai-nilai berikut:
# * Cari nilai terendah dan tertingginya.

# %%
df_15['BMI'].min()
# Out:
# 17.48178980228928

# %%
df_15['BMI'].max()
# Out:
# 28.906249999999993

# %% [markdown]
# * Berapa nilai rata-rata tinggi badan siswa?

# %%
df_15['Tinggi Badan (m)'].mean()
# Out:
# 1.6092

# %% [markdown]
# * Berapa rata-rata berat badan siswa?

# %%
df_15['Berat Badan (kg)'].mean()
# Out:
# 55.68

# %% [markdown]
# * Ada berapa orang jumlah siswa  yang tercatat pada dataframe df?

# %%
df_15['Nama'].count()
# Out:
# 25

# %% [markdown]
# * 5 orang dengan nilai BMI tertinggi.

# %%
df_15.sort_values('BMI', ascending=False).head()
# Out:
#     No. No. Peserta                         Nama  \
# 14   15     SC61515         Litasya Shofwatillah
# 19   20     SC61520                    Beni Amar
# 20   21     SC61521                  Fikri Majid
# 10   11     SC61511              Wahyu Dwi Utomo
# 9    10     SC61510  Sandya Nur Indrawati Karsan
#
#                                Jurusan  Berat Badan (kg)  Tinggi Badan (m)  \
# 14                          Statistika                74              1.60
# 19  Sistem Informasi Kampus Kota Tegal                70              1.70
# 20         Teknologi Rekayasa Komputer                60              1.60
# 10                    Sistem Informasi                73              1.78
# 9                           Matematika                55              1.55
#
#           BMI  BMI_status
# 14  28.906250  Overweight
# 19  24.221453      Normal
# 20  23.437500      Normal
# 10  23.040020      Normal
# 9   22.892820      Normal

# %% [markdown]
# * Ada berapa orang yang tergolong status Underweight, Normal, Overweight, dan Obesity?

# %%
sum(df_15['BMI_status'] == 'Underweight')
# Out:
# 5

# %%
sum(df_15['BMI_status'] == 'Normal')
# Out:
# 19

# %%
sum(df_15['BMI_status'] == 'Overweight')
# Out:
# 1

# %%
sum(df_15['BMI_status'] == 'Obesity')
# Out:
# 0

# %% [markdown]
# **SOAL 2**

# %% [markdown]
# Perusahaan Investasi Jamin-Sugih Co kami memberikan penawaran investasi terbaik dengan pembagian keuntungan tetap sebesar 25% setiap tahun.
#
# Buatlah program Python yang dapat menerima input dari pengguna dalam bentuk:
# Modal Investasi (bilangan bulat antara 0-1.000.000.000)
# Jangka Waktu Investasi (bilangan bulat antara 1-25 dalam tahun)
# Selain itu, program akan menampilkan error message bahwa modal atau tenure tidak sesuai ketentuan.
#
# Program akan menampilkan informasi akumulasi investasi setiap tahun, menggunakan iterasi untuk setiap tahun.

# %%
def investasi():
    x=int(input('Money Capital = '))
    y=int(input('Investment Tenure = '))

    if x<0 or x>1000000000:
        print("Your investment is reaching our limit, we can't handle this.")
    elif y<0 or y>25:
        print("Your investment isn't reaching our time limit.")
    else:
        year=0
        total=x
        for z in range(1,(y+1)):
            year=year+1
            total=(total*0.25)+total
            print('Year', year,',', 'Your total investment= ', total)

# %%
investasi()
# Out:
# Money Capital = 500000
# Investment Tenure = 10000000
# Your investment isn't reaching our time limit.
